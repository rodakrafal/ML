# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from create_model import load_and_process_X, DataSet, Statistics, load_and_process_y
df = pd.read_csv("data/demands/euro28/demands-0.csv", sep=";")

df_X = load_and_process_X(DataSet.EURO26, 1, [Statistics.SUM])
# Out:
# 2024-01-11 16:30:36,623 - INFO - Finished loading DataSet.EURO26 with 1 files and 1 statistics

# %%
df
# Out:
#      source  destination           5          10          15          20  \
# 0        13            0  224.499143  221.801268  220.329618  219.342049
# 1         4           25  109.915177  109.585485  107.811827  108.284943
# 2        17           12  165.913214  164.528457  163.031901  162.296488
# 3        13           19   96.543919   94.714534   95.304071   94.082688
# 4        16           20  175.509517  174.608981  172.790239  172.511350
# ..      ...          ...         ...         ...         ...         ...
# 995       0            1  108.849234  107.959428  106.892567  105.080077
# 996      17            3  155.308427  154.158573  152.852963  151.715488
# 997      11           27  138.333054  136.660989  135.290827  134.533428
# 998      23            1  129.895096  129.754673  126.977312  127.189233
# 999      25           18  170.812190  169.690930  168.342088  166.782988
#
#              25          30          35          40  ...        1395  \
# 0    217.516822  214.442721  213.024729  210.652913  ...  249.075242
# 1    106.997055  105.850465  104.623967  104.601605  ...  122.175884
# 2    161.718518  160.048050  157.774655  156.673283  ...  185.475518
# 3     93.303564   92.867995   91.420595   89.862949  ...  106.244164
# 4    170.502240  168.198411  167.653290  166.083725  ...  195.186247
# ..          ...         ...         ...         ...  ...         ...
# 995  106.102567  103.871935  103.618682  101.858216  ...  121.006922
# 996  150.539161  149.416356  147.279536  146.180810  ...  172.577800
# 997  133.039503  131.466991  130.027077  130.147840  ...  153.423400
# 998  125.999487  123.946791  122.828232  121.909012  ...  144.877617
# 999  166.665507  163.623652  163.452291  161.673706  ...  190.658353
#
#            1400        1405        1410        1415        1420        1425  \
# 0    242.540772  237.929251  235.307556  234.186761  232.880903  231.527132
# 1    120.858393  116.596621  115.810991  115.608330  115.776156  113.654060
# 2    180.288779  176.496659  174.800778  173.547425  173.266443  170.926892
# 3    103.626262  101.904541  100.939673  101.073718  100.572982   99.585952
# 4    191.721728  187.503943  185.785566  183.958882  183.523752  182.041372
# ..          ...         ...         ...         ...         ...         ...
# 995  117.864477  116.258258  113.651110  112.990817  113.872074  113.124474
# 996  168.449856  165.037567  162.417017  161.091634  161.258472  159.900949
# 997  149.217546  146.207521  144.302123  143.893810  143.519025  142.358975
# 998  140.599969  138.261016  135.607924  135.681960  134.808897  134.683785
# 999  185.802080  182.151718  179.977905  178.764789  178.391569  176.990719
#
#            1430        1435        1440
# 0    230.016125  228.159248  225.683825
# 1    112.972231  112.285902  111.758199
# 2    170.514252  168.731205  168.059468
# 3     99.547672   97.287163   97.566074
# 4    179.928526  178.847579  178.239865
# ..          ...         ...         ...
# 995  111.924629  110.847698  110.516458
# 996  159.966420  157.605425  156.828239
# 997  141.460412  139.895202  138.655741
# 998  132.398284  131.649148  130.398892
# 999  175.400179  173.991765  173.042230
#
# [1000 rows x 290 columns]

# %%
df.dtypes
# Out:
# source           int64
# destination      int64
# 5              float64
# 10             float64
# 15             float64
#                 ...
# 1420           float64
# 1425           float64
# 1430           float64
# 1435           float64
# 1440           float64
# Length: 290, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df
# 999  166.665507  163.623652  163.452291  161.673706  ...  190.658353
#
#            1400        1405        1410        1415        1420        1425  \
# 0    242.540772  237.929251  235.307556  234.186761  232.880903  231.527132
# 1    120.858393  116.596621  115.810991  115.608330  115.776156  113.654060
# 2    180.288779  176.496659  174.800778  173.547425  173.266443  170.926892
# 3    103.626262  101.904541  100.939673  101.073718  100.572982   99.585952
# 4    191.721728  187.503943  185.785566  183.958882  183.523752  182.041372
# ..          ...         ...         ...         ...         ...         ...
# 995  117.864477  116.258258  113.651110  112.990817  113.872074  113.124474
# 996  168.449856  165.037567  162.417017  161.091634  161.258472  159.900949
# 997  149.217546  146.207521  144.302123  143.893810  143.519025  142.358975
# 998  140.599969  138.261016  135.607924  135.681960  134.808897  134.683785
# 999  185.802080  182.151718  179.977905  178.764789  178.391569  176.990719
#
#            1430        1435        1440
# 0    230.016125  228.159248  225.683825
# 1    112.972231  112.285902  111.758199
# 2    170.514252  168.731205  168.059468
# 3     99.547672   97.287163   97.566074
# 4    179.928526  178.847579  178.239865
# ..          ...         ...         ...
# 995  111.924629  110.847698  110.516458
# 996  159.966420  157.605425  156.828239
# 997  141.460412  139.895202  138.655741
# 998  132.398284  131.649148  130.398892
# 999  175.400179  173.991765  173.042230
#
# [1000 rows x 290 columns]

# %%
x = list(df.columns[2:])

# %%
for i in range(len(df)):
    plt.plot(x,df.iloc[i][2:])

num_ticks = 10  # for example, change this to the number of ticks you desire

# Set the positions and labels for x-ticks
tick_positions = np.linspace(0, len(x)-1, num_ticks, dtype=int)  # evenly spaced tick positions
tick_labels = [x[pos] for pos in tick_positions]  # get the labels from your data

plt.xticks(tick_positions, tick_labels, rotation=90)

plt.ylabel("Bitrate")
plt.xlabel("Time")
plt.title("Selected demands in a single request set")
plt.savefig('demand_1_partial.png')
plt.ylabel("Bitrate")
plt.xlabel("Time")
plt.title("All demands in a single request set")
plt.savefig('demand_1.png', bbox_inches='tight')
# Out:
# 2024-01-11 16:30:41,840 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,843 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,847 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,849 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,852 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,854 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,857 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,859 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,863 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,865 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,868 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,871 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,874 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,877 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,880 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,882 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,885 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,887 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,891 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,893 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,896 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,898 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,901 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,904 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,907 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,909 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,912 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,914 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,917 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,920 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,923 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,925 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,927 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,929 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,932 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,934 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,938 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,940 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,943 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,945 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,948 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,950 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,953 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,955 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,958 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,961 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,963 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,966 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,969 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,971 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,975 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,979 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,981 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,984 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,987 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,991 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,994 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:41,996 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,000 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,002 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,006 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,009 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,013 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,016 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,019 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,022 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,026 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,030 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,034 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,037 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,047 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,049 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,052 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,055 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,058 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,060 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,063 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,065 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,068 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,070 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,073 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,075 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,078 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,081 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,084 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,087 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,090 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,092 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,095 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,097 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,100 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,102 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,105 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,108 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,111 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,113 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,116 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,118 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,124 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,126 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,135 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,138 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,144 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,146 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,149 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,151 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,154 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,157 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,160 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,164 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,166 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,169 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,171 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,174 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,177 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,179 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,182 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,184 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,187 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,191 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,194 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,196 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,200 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,202 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,205 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,207 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,210 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,214 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,218 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,221 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,224 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,228 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,232 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,235 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,238 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,242 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,245 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,247 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,251 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,254 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,257 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,261 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,264 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,270 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,274 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,276 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,279 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,281 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,284 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,286 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,290 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,293 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,297 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,301 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,305 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,314 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,318 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,321 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,325 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,328 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,333 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,335 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,338 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,341 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,344 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,347 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,351 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,354 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,359 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,362 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,365 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,367 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,371 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,373 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,377 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,379 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,383 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,386 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,389 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,392 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,395 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,402 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,406 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,409 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,412 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,415 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,418 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,420 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,423 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,426 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,430 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,432 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,436 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,439 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,443 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,446 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,451 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,454 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,457 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,459 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,463 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,465 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,468 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,471 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,474 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,477 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,481 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,486 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,488 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,491 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,494 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,500 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,504 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,515 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:42,519 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...
# 2024-01-11 16:30:48,200 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,204 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,207 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,210 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,212 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,217 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,219 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,222 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,224 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,227 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,229 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,231 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,233 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,236 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,240 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,243 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,245 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,248 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,250 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,253 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,256 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,259 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,262 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,264 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,268 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,270 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,272 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,275 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,277 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,280 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,282 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,285 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,287 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,290 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,292 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,295 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,297 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,300 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,302 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,310 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,312 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,315 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,318 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,321 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,323 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,325 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,329 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,332 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,334 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,336 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,337 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,340 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,343 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,346 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,348 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,351 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,356 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,359 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,361 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,365 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,367 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,370 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,372 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,375 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,379 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,382 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,386 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,390 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,394 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,398 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:48,401 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
plt.figure(figsize=(7,5))
for i in range(3):
    plt.plot(x,df.iloc[i][2:])

num_ticks = 10  # for example, change this to the number of ticks you desire

tick_positions = np.linspace(0, len(x)-1, num_ticks, dtype=int)  # evenly spaced tick positions
tick_labels = [x[pos] for pos in tick_positions]  # get the labels from your data

plt.xticks(tick_positions, tick_labels, rotation=90)

plt.ylabel("Bitrate")
plt.xlabel("Time")
plt.title("Selected demands in a single request set")
plt.savefig('demand_1_partial.png', bbox_inches='tight')
# Out:
# 2024-01-11 16:30:50,785 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:50,787 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:50,791 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:50,793 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:50,797 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-01-11 16:30:50,799 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
df_modified = df.copy()
df_modified = df_modified.drop(columns=['source','destination'], axis = 1)

# %%
df_modified
# Out:
#               5          10          15          20          25          30  \
# 0    224.499143  221.801268  220.329618  219.342049  217.516822  214.442721
# 1    109.915177  109.585485  107.811827  108.284943  106.997055  105.850465
# 2    165.913214  164.528457  163.031901  162.296488  161.718518  160.048050
# 3     96.543919   94.714534   95.304071   94.082688   93.303564   92.867995
# 4    175.509517  174.608981  172.790239  172.511350  170.502240  168.198411
# ..          ...         ...         ...         ...         ...         ...
# 995  108.849234  107.959428  106.892567  105.080077  106.102567  103.871935
# 996  155.308427  154.158573  152.852963  151.715488  150.539161  149.416356
# 997  138.333054  136.660989  135.290827  134.533428  133.039503  131.466991
# 998  129.895096  129.754673  126.977312  127.189233  125.999487  123.946791
# 999  170.812190  169.690930  168.342088  166.782988  166.665507  163.623652
#
#              35          40          45          50  ...        1395  \
# 0    213.024729  210.652913  204.979116  197.634901  ...  249.075242
# 1    104.623967  104.601605  100.730303   97.518053  ...  122.175884
# 2    157.774655  156.673283  152.213238  147.134717  ...  185.475518
# 3     91.420595   89.862949   88.035518   85.355184  ...  106.244164
# 4    167.653290  166.083725  161.267698  154.965568  ...  195.186247
# ..          ...         ...         ...         ...  ...         ...
# 995  103.618682  101.858216   99.427055   96.071256  ...  121.006922
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    167.605300   166.287078   165.099734   163.753925   162.583365
# std      48.361403    47.959725    47.651161    47.249747    46.959577
# min      82.249370    81.482405    81.223634    80.154165    79.619014
# 25%     126.335098   125.208312   124.846013   123.249181   122.375663
# 50%     170.362049   168.977418   167.475010   166.267936   164.994374
# 75%     210.694880   209.074589   207.444540   206.100199   204.081828
# max     248.940917   246.920681   245.299211   242.642235   241.450682
#
# [8 rows x 288 columns]

# %%
df_mean = pd.DataFrame()
for i in range(100, 651, 25):
    x = df_modified.iloc[:i][:].mean()
    x = x.to_frame().T
    x['nrOfRequests'] = i
    df_mean = pd.concat([df_mean, x], ignore_index= True)

last_column = df_mean.columns[-1]
new_columns = [last_column] + list(df_mean.columns[:-1])
df_mean = df_mean[new_columns]
df_mean.rename(columns={old_name: f"mean {old_name}" for old_name in df_mean.columns[1:]}, inplace=True)
df_mean
# Out:
#     nrOfRequests      mean 5     mean 10     mean 15     mean 20     mean 25  \
# 0            100  152.793163  151.285233  150.180108  149.340466  148.209808
# 1            125  150.498278  149.046513  147.893615  147.099812  145.977152
# 2            150  150.595682  149.131905  147.996396  147.179926  146.042105
# 3            175  149.350634  147.925998  146.787286  145.957085  144.814246
# 4            200  153.282170  151.845376  150.669651  149.831543  148.663559
# 5            225  154.022062  152.580580  151.409934  150.561586  149.371965
# 6            250  155.208083  153.750469  152.550167  151.704015  150.524490
# 7            275  156.176875  154.714125  153.501814  152.658431  151.457734
# 8            300  156.889311  155.397977  154.189241  153.356228  152.134848
# 9            325  157.221153  155.709914  154.532789  153.675924  152.450870
# 10           350  157.245766  155.735672  154.560135  153.689263  152.482475
# 11           375  157.949491  156.422966  155.254543  154.366111  153.166159
# 12           400  158.315662  156.806470  155.607319  154.714412  153.518565
# 13           425  158.608457  157.096541  155.889567  154.996607  153.790978
# 14           450  159.506011  157.998480  156.763559  155.875095  154.660742
# 15           475  160.546141  159.036639  157.788351  156.898991  155.671106
# 16           500  161.221639  159.716798  158.462885  157.570504  156.333486
# 17           525  161.720988  160.211604  158.953222  158.058737  156.809469
# 18           550  161.322340  159.818923  158.561341  157.671155  156.427220
# 19           575  161.407537  159.902665  158.643836  157.754581  156.508011
# 20           600  160.707697  159.209999  157.954702  157.071763  155.831982
# 21           625  160.391944  158.898595  157.648544  156.755352  155.528677
# 22           650  160.620916  159.118122  157.869890  156.970575  155.739939
#
#        mean 30     mean 35     mean 40     mean 45  ...   mean 1395  \
# 0   146.420304  145.033630  143.739349  139.582241  ...  169.673157
# 1   144.183471  142.870327  141.552676  137.474991  ...  167.167755
# 2   144.242992  142.954044  141.611884  137.579457  ...  167.257117
# 3   143.059386  141.770879  140.456980  136.495906  ...  165.900317
# 4   146.853983  145.535423  144.141711  140.131390  ...  170.320758
# 5   147.568800  146.258501  144.855253  140.831164  ...  171.129336
# 6   148.708487  147.382999  145.983897  141.938776  ...  172.457717
# 7   149.636366  148.286703  146.895909  142.830179  ...  173.514091
# 8   150.309480  148.947109  147.560503  143.462068  ...  174.299307
# 9   150.625247  149.257449  147.874270  143.765427  ...  174.669383
# 10  150.654429  149.270888  147.895854  143.801052  ...  174.707983
# 11  151.311638  149.920589  148.557300  144.433286  ...  175.477270
# 12  151.675801  150.266562  148.901512  144.767941  ...  175.880116
# 13  151.960285  150.539642  149.175936  145.034375  ...  176.200336
# 6   80.154165  79.807788
# 7   80.154165  79.807788
# 8   80.154165  79.807788
# 9   80.154165  79.807788
# 10  80.154165  79.807788
# 11  80.154165  79.807788
# 12  80.154165  79.807788
# 13  80.154165  79.807788
# 14  80.154165  79.807788
# 15  80.154165  79.807788
# 16  80.154165  79.807788
# 17  80.154165  79.807788
# 18  80.154165  79.807788
# 19  80.154165  79.807788
# 20  80.154165  79.807788
# 21  80.154165  79.807788
# 22  80.154165  79.807788
#
# [23 rows x 289 columns]

# %%
pd_partially_merged = pd.merge(df_mean, df_max, on="nrOfRequests")
pd_merged = pd.merge(pd_partially_merged, df_min, on="nrOfRequests")

# %%
2*100*23
# Out:
# 4600

# %%
test = pd.DataFrame()
for i in range(100, 651, 25):
    x = df_modified.iloc[:i][:].min()
    x = x.to_frame().T
    x.rename(columns={old_name: f"min {old_name}" for old_name in x.columns}, inplace=True)
    y = df_modified.iloc[:i][:].max()
    y = y.to_frame().T
    y.rename(columns={old_name: f"max {old_name}" for old_name in y.columns}, inplace=True)
    z = df_modified.iloc[:i][:].mean()
    z = z.to_frame().T
    z.rename(columns={old_name: f"mean {old_name}" for old_name in z.columns}, inplace=True)
    one_row = pd.concat([z, y, x], axis = 1)
    one_row['nrOfRequests'] = i
    test = pd.concat([test, one_row], ignore_index= True)
    
last_column = test.columns[-1]
new_columns = [last_column] + list(test.columns[:-1])
test = test[new_columns]
# df_min.rename(columns={old_name: f"min {old_name}" for old_name in df_min.columns[1:]}, inplace=True)
# df_min
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test = pd.DataFrame()
#       2 for i in range(100, 651, 25):
#       3     x = df_modified.iloc[:i][:].min()
#
# NameError: name 'pd' is not defined

# %%
df_modified
# Out:
#               5          10          15          20          25          30  \
# 0    224.499143  221.801268  220.329618  219.342049  217.516822  214.442721
# 1    109.915177  109.585485  107.811827  108.284943  106.997055  105.850465
# 2    165.913214  164.528457  163.031901  162.296488  161.718518  160.048050
# 3     96.543919   94.714534   95.304071   94.082688   93.303564   92.867995
# 4    175.509517  174.608981  172.790239  172.511350  170.502240  168.198411
# ..          ...         ...         ...         ...         ...         ...
# 995  108.849234  107.959428  106.892567  105.080077  106.102567  103.871935
# 996  155.308427  154.158573  152.852963  151.715488  150.539161  149.416356
# 997  138.333054  136.660989  135.290827  134.533428  133.039503  131.466991
# 998  129.895096  129.754673  126.977312  127.189233  125.999487  123.946791
# 999  170.812190  169.690930  168.342088  166.782988  166.665507  163.623652
#
#              35          40          45          50  ...        1395  \
# 0    213.024729  210.652913  204.979116  197.634901  ...  249.075242
# 1    104.623967  104.601605  100.730303   97.518053  ...  122.175884
# 2    157.774655  156.673283  152.213238  147.134717  ...  185.475518
# 3     91.420595   89.862949   88.035518   85.355184  ...  106.244164
# 4    167.653290  166.083725  161.267698  154.965568  ...  195.186247
# ..          ...         ...         ...         ...  ...         ...
# 995  103.618682  101.858216   99.427055   96.071256  ...  121.006922
# 996  147.279536  146.180810  142.310316  137.573054  ...  172.577800
# 997  130.027077  130.147840  126.253072  121.504201  ...  153.423400
# 998  122.828232  121.909012  118.252273  114.765957  ...  144.877617
# 2299  65726.607423  65847.691672  65565.252254  63519.661728  60743.662047
#
#       ...      sum 1395      sum 1400      sum 1405      sum 1410  \
# 0     ...  16967.315684  16579.759729  16259.722495  16044.971748
# 1     ...  20895.969391  20409.040772  20015.986590  19754.716071
# 2     ...  25088.567490  24508.633393  24033.560884  23716.565715
# 3     ...  29032.555512  28355.971675  27809.794183  27441.669517
# 4     ...  34064.151641  33260.994378  32631.837644  32189.455781
# ...   ...           ...           ...           ...           ...
# 2295  ...  70284.001923  69568.475325  68850.844574  68479.099873
# 2296  ...  73620.427533  72854.483525  72097.229077  71698.464595
# 2297  ...  76153.508864  75364.663570  74587.251012  74178.978384
# 2298  ...  79694.267864  78866.531975  78052.875926  77627.347075
# 2299  ...  83481.873817  82613.708750  81747.050513  81294.123302
#
#           sum 1415      sum 1420      sum 1425      sum 1430      sum 1435  \
# 0     15973.371064  15905.321501  15771.901665  15667.979322  15532.578570
# 1     19663.653541  19579.183695  19416.867300  19289.969840  19125.954350
# 2     23610.763399  23508.290264  23317.425070  23161.166480  22960.227824
# 3     27322.646730  27195.639997  26981.838287  26798.152499  26565.380544
# 4     32048.675344  31900.515161  31656.164670  31434.412678  31166.673427
# ...            ...           ...           ...           ...           ...
# 2295  68117.968224  67113.566846  66047.772190  64382.836275  63104.963876
# 2296  71312.525907  70252.955826  69118.147502  67368.238800  66023.253370
# 2297  73778.214660  72677.843682  71483.706795  69636.712389  68211.939316
# 2298  77202.244067  76055.339785  74807.312684  72869.218840  71373.770967
# 2299  80841.768673  79630.727263  78306.529605  76277.937291  74705.931740
#
#           sum 1440
# 0     15419.102390
# 1     18983.614081
# 2     22800.575154
# 3     26385.288964
# 4     30958.546071
# ...            ...
# 2295  61462.803724
# 2296  64297.693591
# 2297  66386.069028
# 2298  69455.182012
# 2299  72699.266044
#
# [2300 rows x 289 columns]

# %%
from create_model import evaluate_models
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import Lasso, Ridge, ElasticNet

random_state = 41

base_models = [
    KNeighborsRegressor(n_neighbors=3),
    KNeighborsRegressor(n_neighbors=7),
    SVR(),
    DecisionTreeRegressor(random_state=random_state),
    RandomForestRegressor(random_state=random_state),
    GradientBoostingRegressor(random_state=random_state),
    AdaBoostRegressor(random_state=random_state),
    Lasso(random_state=random_state),
    Ridge(random_state=random_state),
    ElasticNet(random_state=random_state),
]

base_metrics_df = evaluate_models(base_models, df_X, df_y.values.ravel(), random_state=random_state, use_pca=False)
pca_metrics_df = evaluate_models(base_models, df_X, df_y.values.ravel(), random_state=random_state, use_pca=True, n_components=0.90)

# Display the DataFrames
print("Base Model Metrics:")
print(base_metrics_df)
print("\nPCA Model Metrics:")
print(pca_metrics_df)
# Out:
# 2024-01-07 23:04:13,796 - INFO - Finished evaluating KNeighborsRegressor (n_neighbors=3)
# 2024-01-07 23:04:14,209 - INFO - Finished evaluating KNeighborsRegressor (n_neighbors=7)
# 2024-01-07 23:04:20,962 - INFO - Finished evaluating SVR
# 2024-01-07 23:04:23,519 - INFO - Finished evaluating DecisionTreeRegressor
# 2024-01-07 23:06:49,761 - INFO - Finished evaluating RandomForestRegressor
# 2024-01-07 23:08:12,192 - INFO - Finished evaluating GradientBoostingRegressor
# 2024-01-07 23:08:38,455 - INFO - Finished evaluating AdaBoostRegressor
# 2024-01-07 23:08:39,700 - INFO - Finished evaluating Lasso
# 2024-01-07 23:08:40,243 - INFO - Finished evaluating Ridge
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.977e+05, tolerance: 5.931e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.692e+05, tolerance: 6.102e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.203e+05, tolerance: 6.145e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.407e+05, tolerance: 5.867e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.665e+05, tolerance: 5.976e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.412e+05, tolerance: 6.058e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.597e+05, tolerance: 5.911e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.384e+05, tolerance: 6.111e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.516e+05, tolerance: 5.862e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.193e+05, tolerance: 6.171e+03
#   model = cd_fast.enet_coordinate_descent(
# 2024-01-07 23:08:42,535 - INFO - Finished evaluating ElasticNet
# 2024-01-07 23:08:44,213 - INFO - Finished evaluating KNeighborsRegressor (n_neighbors=3)
# 2024-01-07 23:08:45,468 - INFO - Finished evaluating KNeighborsRegressor (n_neighbors=7)
# 2024-01-07 23:08:48,398 - INFO - Finished evaluating SVR
# 2024-01-07 23:08:49,748 - INFO - Finished evaluating DecisionTreeRegressor
# 2024-01-07 23:08:53,485 - INFO - Finished evaluating RandomForestRegressor
# 2024-01-07 23:08:56,382 - INFO - Finished evaluating GradientBoostingRegressor
# 2024-01-07 23:08:58,093 - INFO - Finished evaluating AdaBoostRegressor
# 2024-01-07 23:08:59,588 - INFO - Finished evaluating Lasso
# 2024-01-07 23:09:01,359 - INFO - Finished evaluating Ridge
# 2024-01-07 23:09:02,824 - INFO - Finished evaluating ElasticNet
# Base Model Metrics:
#                                  Model  R^2 Score          MSE        MAE
# 0  KNeighborsRegressor (n_neighbors=3)   0.996031   207.386948   8.670742
# 1  KNeighborsRegressor (n_neighbors=7)   0.992860   373.057014  10.861291
# 2                                  SVR   0.892392  5631.645546  46.788292
# 3                DecisionTreeRegressor   0.997130   150.021718   6.698786
# 4                RandomForestRegressor   0.997803   114.809656   6.241710
# 5            GradientBoostingRegressor   0.997995   104.784722   7.316962
# 6                    AdaBoostRegressor   0.996024   207.981958  11.126505
# 7                                Lasso   0.980068  1041.960484  27.471647
# 8                                Ridge   0.980562  1016.173456  27.094781
# 9                           ElasticNet   0.974927  1310.734384  29.614223
#
# PCA Model Metrics:
#                                  Model  R^2 Score          MSE        MAE
# 0  KNeighborsRegressor (n_neighbors=3)   0.963016  1931.416127  20.179719
# 1  KNeighborsRegressor (n_neighbors=7)   0.967210  1712.757166  20.049090
# 2                                  SVR   0.890543  5727.152118  46.745049
# 3                DecisionTreeRegressor   0.957436  2223.789557  16.257513
# 4                RandomForestRegressor   0.964297  1865.412630  17.345610
# 5            GradientBoostingRegressor   0.968858  1627.009764  17.812177
# 6                    AdaBoostRegressor   0.938092  3238.156367  41.118341
# 7                                Lasso   0.939633  3153.244259  36.964193
# 8                                Ridge   0.939632  3153.254658  36.954823
# 9                           ElasticNet   0.939632  3153.310440  37.023050

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import LearningCurveDisplay, RepeatedKFold

common_params = {
    "X": df_X,
    "y": df_y.values.ravel(),
    "train_sizes": np.linspace(0.1, 1.0, 5),
    "cv": RepeatedKFold(n_splits=2, n_repeats=5, random_state=random_state),
    "score_type": "both",
    "n_jobs": 4,
    "line_kw": {"marker": "o"},
    "std_display_style": "fill_between",
    "score_name": "r2",
}

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 6), sharey=True)

for ax_idx, estimator in enumerate([GradientBoostingRegressor(random_state=random_state)]):
    model_name = type(estimator).__name__
    if hasattr(estimator, 'n_neighbors'):
        model_name += f" (n_neighbors={estimator.n_neighbors})"
    LearningCurveDisplay.from_estimator(estimator, **common_params, ax=ax[ax_idx])
    handles, label = ax[ax_idx].get_legend_handles_labels()
    ax[ax_idx].legend(handles[:2], ["Training Score", "Test Score"])
    ax[ax_idx].set_title(f"Learning Curve for {model_name}")
# Out:
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/rrodak/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import make_scorer

# Define a pipeline that includes scaling, PCA, and the GradientBoostingRegressor
base_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('gbr', GradientBoostingRegressor(random_state=41))
])

pca_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=n_components)),
    ('gbr', GradientBoostingRegressor(random_state=41))
])

param_grid = {
    'gbr__n_estimators': [100, 200, 300],
    'gbr__learning_rate': [0.01, 0.1, 0.2],
    'gbr__max_depth': [3, 4, 5],
    'gbr__min_samples_split': [2, 4],
    'gbr__min_samples_leaf': [1, 2],
    'gbr__max_features': [None, 'sqrt', 'log2']
}

scoring = {
    'r2': make_scorer(r2_score),
    'mse': make_scorer(mean_squared_error, greater_is_better=False),
    'mae': make_scorer(mean_absolute_error, greater_is_better=False)
}

piplines = [
    {
        'pipline': base_pipeline,
        'name': "Without PCA ",
        "best_params": None
    },
    {
        'pipline': pca_pipeline,
        'name': "With PCA",
        "best_params": None
    }
]


# Set up the GridSearchCV object
for pipline in piplines:
    grid_search = GridSearchCV(pipline["pipline"], param_grid , cv=rskf, scoring=scoring, n_jobs=-1, verbose=1, refit='r2', return_train_score=True)
    
    # Fit the GridSearchCV object to the data
    grid_search.fit(X, y)
    
    best_params = grid_search.best_params_
    best_r2_score = grid_search.cv_results_['mean_test_r2'][grid_search.best_index_]
    best_mse_score = -grid_search.cv_results_['mean_test_mse'][grid_search.best_index_]  # negative because greater_is_better=False
    best_mae_score = -grid_search.cv_results_['mean_test_mae'][grid_search.best_index_]  # negative because greater_is_better=False
    pipline["best_params"] = best_params
    name = pipline["name"]
    # Print the best parameters and the corresponding scores
    print(f"\n{name}")
    print("Best parameters:", best_params)
    print("Best R^2 score:", best_r2_score)
    print("Best MSE score:", best_mse_score)
    print("Best MAE score:", best_mae_score)
# Out:
# Fitting 10 folds for each of 324 candidates, totalling 3240 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 52
#      49 grid_search = GridSearchCV(pipline["pipline"], param_grid , cv=rskf, scoring=scoring, n_jobs=-1, verbose=1, refit='r2', return_train_score=True)
#      51 # Fit the GridSearchCV object to the data
# ---> 52 grid_search.fit(X, y)
#      54 best_params = grid_search.best_params_
#      55 best_r2_score = grid_search.cv_results_['mean_test_r2'][grid_search.best_index_]
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/studia/magister/2_semestr/ML/venv/lib/python3.10/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
import json

best_params = piplines[0]["best_params"]
best_pca_params = piplines[1]["best_params"]

formatted_params = {k.replace('gbr__', ''): v for k, v in best_params.items()}
formatted_pca_params = {k.replace('gbr__', ''): v for k, v in best_pca_params.items()}


with open('best_params.json', 'w') as f:
    json.dump(formatted_params, f)

with open('best_params_with_pca.json', 'w') as f:
    json.dump(formatted_pca_params, f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 6
#       3 best_params = piplines[0]["best_params"]
#       4 best_pca_params = piplines[1]["best_params"]
# ----> 6 formatted_params = {k.replace('gbr__', ''): v for k, v in best_params.items()}
#       7 formatted_pca_params = {k.replace('gbr__', ''): v for k, v in best_pca_params.items()}
#      10 with open('best_params.json', 'w') as f:
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
from sklearn.model_selection import cross_val_score

with open('best_params.json', 'r') as f:
    loaded_params = json.load(f)

final_model = GradientBoostingRegressor(**loaded_params, random_state=41)
final_pca_pipeline = make_pipeline(
    StandardScaler(),
    PCA(n_components=n_components),
    final_model  # Unpack the parameters
)

final_pca_pipeline.fit(X, y)

final_r2_scores = cross_val_score(final_model, X, y, cv=rskf, scoring='r2', n_jobs=-1)
final_mse_scores = cross_val_score(final_model, X, y, cv=rskf, scoring='neg_mean_squared_error', n_jobs=-1)
final_mae_scores = cross_val_score(final_model, X, y, cv=rskf, scoring='neg_mean_absolute_error', n_jobs=-1)

# Calculate the mean and standard deviation for the final evaluation metrics
mean_r2 = np.mean(final_r2_scores)
std_r2 = np.std(final_r2_scores)
mean_mse = -np.mean(final_mse_scores)  # Negate because 'neg_mean_squared_error' is used
std_mse = np.std(final_mse_scores)
mean_mae = -np.mean(final_mae_scores)  # Negate because 'neg_mean_absolute_error' is used
std_mae = np.std(final_mae_scores)

# Print the final evaluation metrics
print(f'Final R^2 score: {mean_r2} (std {std_r2})')
print(f'Final MSE score: {mean_mse} (std {std_mse})')
print(f'Final MAE score: {mean_mae} (std {std_mae})')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       1 from sklearn.model_selection import cross_val_score
#       3 with open('best_params.json', 'r') as f:
# ----> 4     loaded_params = json.load(f)
#       6 final_model = GradientBoostingRegressor(**loaded_params, random_state=41)
#       7 final_pca_pipeline = make_pipeline(
#       8     StandardScaler(),
#       9     PCA(n_components=n_components),
#      10     final_model  # Unpack the parameters
#      11 )
#
# NameError: name 'json' is not defined

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = learning_curve(
    final_pca_pipeline, X, y, cv=rskf, scoring='r2', n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10)
)

# Calculate the mean and standard deviation for the training and test sets
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve for the pipeline including PCA
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_mean, 'o-', color="g", label="Cross-validation score")

plt.title("Learning Curve for GradientBoostingRegressor with PCA")
plt.xlabel("Training examples")
plt.ylabel("R^2 Score")
plt.legend(loc="best")
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Define the parameter grids
param_grid_gbr = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3],
}

param_grid_rfr = {
    'n_estimators': [100, 200, 300],
    'max_features': [None, 'sqrt', 'log2'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

param_grid_knr = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
}

# Set up the model base with PCA and without PCA
NUM_TRIALS = 1
n_components = 2

# Model base definitions without PCA
model_bases = {
    'RandomForestRegressor': RandomForestRegressor(random_state=42),
    'GradientBoostingRegressor': GradientBoostingRegressor(random_state=42),
    'KNeighborsRegressor': KNeighborsRegressor()
}

# Model base definitions with PCA
model_bases_with_pca = {
    'RandomForestRegressor': make_pipeline(StandardScaler(), PCA(n_components=n_components), RandomForestRegressor(random_state=42)),
    'GradientBoostingRegressor': make_pipeline(StandardScaler(), PCA(n_components=n_components), GradientBoostingRegressor(random_state=42)),
    'KNeighborsRegressor': make_pipeline(StandardScaler(), PCA(n_components=n_components), KNeighborsRegressor())
}

# Parameter grids for each model
param_grids = {
    'RandomForestRegressor': param_grid_rfr,
    'GradientBoostingRegressor': param_grid_gbr,
    'KNeighborsRegressor': param_grid_knr
}

# Arrays to store scores for models without PCA and with PCA
non_nested_scores = {name: np.zeros(NUM_TRIALS) for name in model_bases}
nested_scores = {name: np.zeros(NUM_TRIALS) for name in model_bases}
best_params = {name: [] for name in model_bases}

non_nested_scores_pca = {name: np.zeros(NUM_TRIALS) for name in model_bases}
nested_scores_pca = {name: np.zeros(NUM_TRIALS) for name in model_bases}
best_params_pca = {name: [] for name in model_bases}

# Loop for each trial and each model
for i in range(NUM_TRIALS):
    for name in model_bases:
        # Choose cross-validation techniques for the inner and outer loops
        inner_cv = KFold(n_splits=4, shuffle=True, random_state=i)
        outer_cv = KFold(n_splits=4, shuffle=True, random_state=i)

        # Non-nested parameter search and scoring without PCA
        # nested vs not nested -> https://scikit-learn.org/stable/auto_examples/model_selection/plot_nested_cross_validation_iris.html
        # gridsearchCV -> https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
        # LogisticRegressionCV -> https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegressionCV.html#sklearn.linear_model.LogisticRegressionCV
        clf = GridSearchCV(estimator=model_bases[name], param_grid=param_grids[name], cv=inner_cv, scoring='r2')
        clf.fit(X, y)
        non_nested_scores[name][i] = clf.best_score_
        best_params[name].append(clf.best_params_)

        # Nested CV with parameter optimization without PCA
        nested_score = cross_val_score(clf, X=X, y=y, cv=outer_cv, scoring='r2')
        nested_scores[name][i] = nested_score.mean()

        # Repeat the process with PCA
      
        clf_with_pca = GridSearchCV(estimator=model_bases_with_pca[name], param_grid=param_grids[name], cv=inner_cv, scoring='r2')
        clf_with_pca.fit(X, y)
        non_nested_scores_pca[name][i] = clf_with_pca.best_score_
        best_params_pca[name].append(clf_with_pca.best_params_)

        # Nested CV with parameter optimization with PCA
        nested_score_pca = cross_val_score(clf_with_pca, X=X, y=y, cv=outer_cv, scoring='r2')
        nested_scores_pca[name][i] = nested_score_pca.mean()


# Calculate the difference in scores between the non-nested and nested cross-validation for each model
for name in model_bases:
    score_difference = non_nested_scores[name] - nested_scores[name]
    score_difference_pca = non_nested_scores_pca[name] - nested_scores_pca[name]
    print(f"Model: {name}")
    print(f"Without PCA - Average difference of {score_difference.mean():.6f} with std. dev. of {score_difference.std():.6f}.")
    print(f"With PCA - Average difference of {score_difference_pca.mean():.6f} with std. dev. of {score_difference_pca.std():.6f}.")

    # Best parameters for each trial without PCA
    print("Best parameters without PCA for each trial:", best_params[name])
    # Best parameters for each trial with PCA
    print("Best parameters with PCA for each trial:", best_params_pca[name])

    plt.figure(figsize=(12, 10))

    plt.subplot(221)
    plt.plot(non_nested_scores[name], color='r', label='Non-Nested CV')
    plt.plot(nested_scores[name], color='b', label='Nested CV')
    plt.title(f'Non-Nested vs Nested CV - {name} (without PCA)')
    plt.xlabel('Trial #')
    plt.ylabel('Score')
    plt.legend()

    plt.subplot(222)
    plt.bar(range(NUM_TRIALS), score_difference)
    plt.title(f'Score Difference - {name} (without PCA)')
    plt.xlabel('Trial #')
    plt.ylabel('Score Difference')

    # Plot scores on each trial for nested and non-nested CV for each model with PCA
    plt.subplot(223)
    plt.plot(non_nested_scores_pca[name], color='r', label='Non-Nested CV')
    plt.plot(nested_scores_pca[name], color='b', label='Nested CV')
    plt.title(f'Non-Nested vs Nested CV - {name} (with PCA)')
    plt.xlabel('Trial #')
    plt.ylabel('Score')
    plt.legend()

    plt.subplot(224)
    plt.bar(range(NUM_TRIALS), score_difference_pca)
    plt.title(f'Score Difference - {name} (with PCA)')
    plt.xlabel('Trial #')
    plt.ylabel('Score Difference')

    plt.tight_layout()
    plt.show()
